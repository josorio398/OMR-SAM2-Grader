# %% [markdown]
# # 🎓 OMR SAM-2 Grader (Google Colab)
#
# Este notebook ejecuta el flujo completo:
# - Clona el repositorio
# - Instala dependencias
# - Ejecuta el pipeline y solicita subir un PDF
# - Descarga automáticamente:
#   - `Resultados_Masivos_Salon.xlsx`
#   - `outputs/Imagenes_Diagnostico.zip` (debug organizado en `debug/input` y `debug/output`)
#
# > **Nota:** Recomendado ejecutar con GPU (Runtime → Change runtime type → GPU).

# %%
#@title 🧩 1) Clonar repo e instalar dependencias

# ⬇️ Reemplaza esta URL por la de tu repo
REPO_URL = "https://github.com/<TU_USUARIO>/OMR-SAM-2-Grader.git"

# !git clone -q {REPO_URL}
# %cd OMR-SAM-2-Grader

# !pip install -q -r requirements.txt

import torch
print(f"✅ Entorno listo en: {'GPU (CUDA)' if torch.cuda.is_available() else 'CPU'}")
print("🚀 Dependencias instaladas.")

# %%
#@title ✅ 2) (Opcional) Smoke test del entorno

# !python scripts/smoke_test.py

# %%
#@title 🚀 3) Ejecutar OMR (sube tu PDF cuando se solicite)

from omr_sam2_grader.colab_entry import run
run()
